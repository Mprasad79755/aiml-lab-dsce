# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657

# %%
x = df[['AREA']]
y = df['PRICE']

# %%
plt.scatter(x,y,color="green")

# %%
xtrain, xtest, ytrain,ytest = train_test_split(x,y, test_size = 0.2, random_state = 100)

# %%
xtest.shape[0]
# Out:
# 10

# %%
model = LinearRegression()

# %%
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
op = model.predict(np.array([[2500], [2000]]))
op
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17463.9064441 , 13005.22094663])

# %%
op = model.predict(np.array([[2500], [2000]]))
print(op)
# Out:
# [17463.9064441  13005.22094663]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("R² score:", model.score(xtest, ytest))
print("R² score training data:", model.score(xtrain, ytrain))
# Out:
# Coefficient: [7.75979089]
# Intercept: -3103.34066448488
# R² score: 0.570954870212099
# R² score training data: 0.865632112064227

# %%
plt.scatter(xtrain, ytrain)
plt.scatter(xtest, ytest, color="red")
plt.plot(xtrain,model.predict(xtrain), color='orange')
